# %%
# Загрузка зависимостей
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import keras
from keras.models import Sequential
from keras.layers import Dense
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from scipy import stats
from statsmodels.graphics.gofplots import qqplot
# Out:
# Using TensorFlow backend.

# %%
# Загрузка подготовленного набора данных
dataset = pd.read_csv('prepared_data.csv')
dataset.head(10)
# Out:
#    base_fond  science_fond       ams  n_buildings    n_days    guests  \
# 0   0.871895      0.681744  0.000000     0.000000  0.938635  0.480550
# 1   0.665213      0.705233  0.220794     0.309087  0.945497  0.772254
# 2   0.819225      0.623368  0.000000     0.000000  0.860134  0.557937
# 3  -0.220496      0.580591  0.129641     0.000000  0.994121  0.667010
# 4   0.407500      0.721147  0.103005     0.077793  0.860134  0.344968
# 5   0.695033      0.704603  0.119234     0.000000  0.870074  0.387616
# 6  -1.312439      0.420758  0.000000     0.000000  0.931638  0.814199
# 7  -0.230401      0.528075  0.112309     0.000000  0.870074  0.165778
# 8   0.200020      0.638670  0.064135     0.137486  0.940937  0.498323
# 9  -0.787443      0.561033  0.000000     0.000000  0.885153  0.293394
#
#    employees
# 0   0.465093
# 1   0.593582
# 2   0.465093
# 3   0.370512
# 4   0.258977
# 5   0.176779
# 6   0.541836
# 7   0.111535
# 8   0.482047
# 9   0.176779

# %%
X = dataset.iloc[:, [*range(0,5),6]].values
Y = dataset['guests'].values

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.2)

# %%
# Задаем параметры структуры нейронной сети.


input_layer_size = 6


first_hidden_layer_size = 15
second_hidden_layer_size = 70

output_layer_size = 1


epochs_number = 70
batch_size = 16

# %%
# Создание нейронной сети прямого распространения, пока она пустая, т.е. не содержит слоёв и нейронов.
model = Sequential()

# Входной слой и первый скрытый слой, функция активации - ReLU
model.add(Dense(first_hidden_layer_size, input_dim=input_layer_size, activation='relu'))

model.add(Dense(second_hidden_layer_size, activation='relu'))




model.add(Dense(output_layer_size, activation='linear'))

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 15)                105
# _________________________________________________________________
# dense_2 (Dense)              (None, 70)                1120
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 71
# =================================================================
# Total params: 1,296
# Trainable params: 1,296
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Настройка нейронной сети.
model.compile(loss='mean_squared_error', optimizer='adam', metrics=['mean_absolute_error', 'mean_squared_error'])

# %%
# Обучение нейронной сети.
history = model.fit(X_train, Y_train, validation_data = (X_test,Y_test), epochs=epochs_number, batch_size=batch_size)
# Out:
# Train on 1819 samples, validate on 455 samples
# Epoch 1/70
# 1819/1819 [==============================] - 1s 420us/step - loss: 0.0409 - mean_absolute_error: 0.1489 - mean_squared_error: 0.0409 - val_loss: 0.0183 - val_mean_absolute_error: 0.1053 - val_mean_squared_error: 0.0183
# Epoch 2/70
# 1819/1819 [==============================] - 0s 193us/step - loss: 0.0184 - mean_absolute_error: 0.1063 - mean_squared_error: 0.0184 - val_loss: 0.0154 - val_mean_absolute_error: 0.0986 - val_mean_squared_error: 0.0154
# Epoch 3/70
# 1819/1819 [==============================] - 0s 185us/step - loss: 0.0170 - mean_absolute_error: 0.1028 - mean_squared_error: 0.0170 - val_loss: 0.0159 - val_mean_absolute_error: 0.1014 - val_mean_squared_error: 0.0159
# Epoch 4/70
# 1819/1819 [==============================] - 0s 198us/step - loss: 0.0166 - mean_absolute_error: 0.1009 - mean_squared_error: 0.0166 - val_loss: 0.0142 - val_mean_absolute_error: 0.0941 - val_mean_squared_error: 0.0142
# Epoch 5/70
# 1819/1819 [==============================] - 0s 184us/step - loss: 0.0166 - mean_absolute_error: 0.1021 - mean_squared_error: 0.0166 - val_loss: 0.0147 - val_mean_absolute_error: 0.0968 - val_mean_squared_error: 0.0147
# Epoch 6/70
# 1819/1819 [==============================] - 0s 191us/step - loss: 0.0157 - mean_absolute_error: 0.0981 - mean_squared_error: 0.0157 - val_loss: 0.0139 - val_mean_absolute_error: 0.0935 - val_mean_squared_error: 0.0139
# Epoch 7/70
# 1819/1819 [==============================] - 0s 180us/step - loss: 0.0157 - mean_absolute_error: 0.0985 - mean_squared_error: 0.0157 - val_loss: 0.0141 - val_mean_absolute_error: 0.0939 - val_mean_squared_error: 0.0141
# Epoch 8/70
# 1819/1819 [==============================] - 0s 198us/step - loss: 0.0154 - mean_absolute_error: 0.0974 - mean_squared_error: 0.0154 - val_loss: 0.0141 - val_mean_absolute_error: 0.0945 - val_mean_squared_error: 0.0141
# Epoch 9/70
# 1819/1819 [==============================] - 0s 189us/step - loss: 0.0152 - mean_absolute_error: 0.0970 - mean_squared_error: 0.0152 - val_loss: 0.0147 - val_mean_absolute_error: 0.0958 - val_mean_squared_error: 0.0147
# Epoch 10/70
# 1819/1819 [==============================] - 0s 192us/step - loss: 0.0153 - mean_absolute_error: 0.0969 - mean_squared_error: 0.0153 - val_loss: 0.0139 - val_mean_absolute_error: 0.0937 - val_mean_squared_error: 0.0139
# Epoch 11/70
# 1819/1819 [==============================] - 0s 174us/step - loss: 0.0149 - mean_absolute_error: 0.0957 - mean_squared_error: 0.0149 - val_loss: 0.0138 - val_mean_absolute_error: 0.0936 - val_mean_squared_error: 0.0138
# Epoch 12/70
# 1819/1819 [==============================] - 0s 182us/step - loss: 0.0154 - mean_absolute_error: 0.0969 - mean_squared_error: 0.0154 - val_loss: 0.0141 - val_mean_absolute_error: 0.0951 - val_mean_squared_error: 0.0141
# Epoch 13/70
# 1819/1819 [==============================] - 0s 191us/step - loss: 0.0149 - mean_absolute_error: 0.0961 - mean_squared_error: 0.0149 - val_loss: 0.0150 - val_mean_absolute_error: 0.0974 - val_mean_squared_error: 0.0150
# Epoch 14/70
# 1819/1819 [==============================] - 0s 182us/step - loss: 0.0150 - mean_absolute_error: 0.0962 - mean_squared_error: 0.0150 - val_loss: 0.0153 - val_mean_absolute_error: 0.0980 - val_mean_squared_error: 0.0153
# Epoch 15/70
# 1819/1819 [==============================] - 0s 185us/step - loss: 0.0149 - mean_absolute_error: 0.0967 - mean_squared_error: 0.0149 - val_loss: 0.0133 - val_mean_absolute_error: 0.0921 - val_mean_squared_error: 0.0133
# Epoch 16/70
# 1819/1819 [==============================] - 0s 180us/step - loss: 0.0145 - mean_absolute_error: 0.0948 - mean_squared_error: 0.0145 - val_loss: 0.0138 - val_mean_absolute_error: 0.0933 - val_mean_squared_error: 0.0138
# Epoch 17/70
# 1819/1819 [==============================] - 0s 185us/step - loss: 0.0151 - mean_absolute_error: 0.0967 - mean_squared_error: 0.0151 - val_loss: 0.0146 - val_mean_absolute_error: 0.0970 - val_mean_squared_error: 0.0146
# Epoch 18/70
# 1819/1819 [==============================] - 0s 191us/step - loss: 0.0148 - mean_absolute_error: 0.0954 - mean_squared_error: 0.0148 - val_loss: 0.0134 - val_mean_absolute_error: 0.0920 - val_mean_squared_error: 0.0134
# Epoch 19/70
# 1819/1819 [==============================] - 0s 179us/step - loss: 0.0146 - mean_absolute_error: 0.0950 - mean_squared_error: 0.0146 - val_loss: 0.0132 - val_mean_absolute_error: 0.0916 - val_mean_squared_error: 0.0132
# Epoch 20/70
# 1819/1819 [==============================] - 0s 179us/step - loss: 0.0145 - mean_absolute_error: 0.0944 - mean_squared_error: 0.0145 - val_loss: 0.0144 - val_mean_absolute_error: 0.0969 - val_mean_squared_error: 0.0144
# Epoch 21/70
# 1819/1819 [==============================] - 0s 183us/step - loss: 0.0146 - mean_absolute_error: 0.0947 - mean_squared_error: 0.0146 - val_loss: 0.0140 - val_mean_absolute_error: 0.0942 - val_mean_squared_error: 0.0140
# Epoch 22/70
# 1819/1819 [==============================] - 0s 167us/step - loss: 0.0143 - mean_absolute_error: 0.0939 - mean_squared_error: 0.0143 - val_loss: 0.0144 - val_mean_absolute_error: 0.0970 - val_mean_squared_error: 0.0144
# Epoch 23/70
# 1819/1819 [==============================] - 0s 186us/step - loss: 0.0143 - mean_absolute_error: 0.0937 - mean_squared_error: 0.0143 - val_loss: 0.0144 - val_mean_absolute_error: 0.0972 - val_mean_squared_error: 0.0144
# Epoch 24/70
# 1819/1819 [==============================] - 0s 171us/step - loss: 0.0145 - mean_absolute_error: 0.0942 - mean_squared_error: 0.0145 - val_loss: 0.0134 - val_mean_absolute_error: 0.0922 - val_mean_squared_error: 0.0134
# Epoch 25/70
# 1819/1819 [==============================] - 0s 199us/step - loss: 0.0145 - mean_absolute_error: 0.0951 - mean_squared_error: 0.0145 - val_loss: 0.0135 - val_mean_absolute_error: 0.0927 - val_mean_squared_error: 0.0135
# Epoch 26/70
# 1819/1819 [==============================] - 0s 169us/step - loss: 0.0145 - mean_absolute_error: 0.0944 - mean_squared_error: 0.0145 - val_loss: 0.0132 - val_mean_absolute_error: 0.0918 - val_mean_squared_error: 0.0132
# Epoch 27/70
# 1819/1819 [==============================] - 0s 179us/step - loss: 0.0143 - mean_absolute_error: 0.0934 - mean_squared_error: 0.0143 - val_loss: 0.0136 - val_mean_absolute_error: 0.0930 - val_mean_squared_error: 0.0136
# Epoch 28/70
# 1819/1819 [==============================] - 0s 185us/step - loss: 0.0143 - mean_absolute_error: 0.0937 - mean_squared_error: 0.0143 - val_loss: 0.0132 - val_mean_absolute_error: 0.0921 - val_mean_squared_error: 0.0132
# Epoch 29/70
# 1819/1819 [==============================] - 0s 176us/step - loss: 0.0145 - mean_absolute_error: 0.0946 - mean_squared_error: 0.0145 - val_loss: 0.0143 - val_mean_absolute_error: 0.0957 - val_mean_squared_error: 0.0143
# Epoch 30/70
# 1819/1819 [==============================] - 0s 180us/step - loss: 0.0145 - mean_absolute_error: 0.0949 - mean_squared_error: 0.0145 - val_loss: 0.0140 - val_mean_absolute_error: 0.0940 - val_mean_squared_error: 0.0140
# Epoch 31/70
# 1819/1819 [==============================] - 0s 184us/step - loss: 0.0142 - mean_absolute_error: 0.0933 - mean_squared_error: 0.0142 - val_loss: 0.0138 - val_mean_absolute_error: 0.0938 - val_mean_squared_error: 0.0138
# Epoch 32/70
# 1819/1819 [==============================] - 0s 175us/step - loss: 0.0143 - mean_absolute_error: 0.0943 - mean_squared_error: 0.0143 - val_loss: 0.0133 - val_mean_absolute_error: 0.0925 - val_mean_squared_error: 0.0133
# Epoch 33/70
# 1819/1819 [==============================] - 0s 183us/step - loss: 0.0140 - mean_absolute_error: 0.0929 - mean_squared_error: 0.0140 - val_loss: 0.0130 - val_mean_absolute_error: 0.0913 - val_mean_squared_error: 0.0130
# Epoch 34/70
# 1819/1819 [==============================] - 0s 197us/step - loss: 0.0142 - mean_absolute_error: 0.0929 - mean_squared_error: 0.0142 - val_loss: 0.0135 - val_mean_absolute_error: 0.0938 - val_mean_squared_error: 0.0135
# Epoch 35/70
# 1819/1819 [==============================] - 0s 185us/step - loss: 0.0139 - mean_absolute_error: 0.0924 - mean_squared_error: 0.0139 - val_loss: 0.0133 - val_mean_absolute_error: 0.0921 - val_mean_squared_error: 0.0133
# Epoch 36/70
# 1819/1819 [==============================] - 0s 178us/step - loss: 0.0140 - mean_absolute_error: 0.0930 - mean_squared_error: 0.0140 - val_loss: 0.0133 - val_mean_absolute_error: 0.0922 - val_mean_squared_error: 0.0133
# Epoch 37/70
# 1819/1819 [==============================] - 0s 183us/step - loss: 0.0141 - mean_absolute_error: 0.0928 - mean_squared_error: 0.0141 - val_loss: 0.0133 - val_mean_absolute_error: 0.0920 - val_mean_squared_error: 0.0133
# Epoch 38/70
# 1819/1819 [==============================] - 0s 185us/step - loss: 0.0141 - mean_absolute_error: 0.0932 - mean_squared_error: 0.0141 - val_loss: 0.0143 - val_mean_absolute_error: 0.0946 - val_mean_squared_error: 0.0143
# Epoch 39/70
# 1819/1819 [==============================] - 0s 182us/step - loss: 0.0142 - mean_absolute_error: 0.0938 - mean_squared_error: 0.0142 - val_loss: 0.0132 - val_mean_absolute_error: 0.0922 - val_mean_squared_error: 0.0132
# Epoch 40/70
# 1819/1819 [==============================] - 0s 202us/step - loss: 0.0139 - mean_absolute_error: 0.0925 - mean_squared_error: 0.0139 - val_loss: 0.0132 - val_mean_absolute_error: 0.0920 - val_mean_squared_error: 0.0132
# Epoch 41/70
# 1819/1819 [==============================] - 0s 189us/step - loss: 0.0140 - mean_absolute_error: 0.0929 - mean_squared_error: 0.0140 - val_loss: 0.0131 - val_mean_absolute_error: 0.0919 - val_mean_squared_error: 0.0131
# Epoch 42/70
# 1819/1819 [==============================] - 0s 206us/step - loss: 0.0141 - mean_absolute_error: 0.0931 - mean_squared_error: 0.0141 - val_loss: 0.0134 - val_mean_absolute_error: 0.0926 - val_mean_squared_error: 0.0134
# Epoch 43/70
# 1819/1819 [==============================] - 0s 198us/step - loss: 0.0144 - mean_absolute_error: 0.0944 - mean_squared_error: 0.0144 - val_loss: 0.0132 - val_mean_absolute_error: 0.0922 - val_mean_squared_error: 0.0132
# Epoch 44/70
# 1819/1819 [==============================] - 0s 188us/step - loss: 0.0139 - mean_absolute_error: 0.0926 - mean_squared_error: 0.0139 - val_loss: 0.0135 - val_mean_absolute_error: 0.0929 - val_mean_squared_error: 0.0135
# Epoch 45/70
# 1819/1819 [==============================] - 0s 181us/step - loss: 0.0139 - mean_absolute_error: 0.0928 - mean_squared_error: 0.0139 - val_loss: 0.0137 - val_mean_absolute_error: 0.0944 - val_mean_squared_error: 0.0137
# Epoch 46/70
# 1819/1819 [==============================] - 0s 185us/step - loss: 0.0139 - mean_absolute_error: 0.0927 - mean_squared_error: 0.0139 - val_loss: 0.0133 - val_mean_absolute_error: 0.0926 - val_mean_squared_error: 0.0133
# Epoch 47/70
# 1819/1819 [==============================] - 0s 184us/step - loss: 0.0139 - mean_absolute_error: 0.0931 - mean_squared_error: 0.0139 - val_loss: 0.0137 - val_mean_absolute_error: 0.0932 - val_mean_squared_error: 0.0137
# Epoch 48/70
# 1819/1819 [==============================] - 0s 182us/step - loss: 0.0140 - mean_absolute_error: 0.0930 - mean_squared_error: 0.0140 - val_loss: 0.0138 - val_mean_absolute_error: 0.0935 - val_mean_squared_error: 0.0138
# Epoch 49/70
# 1819/1819 [==============================] - 0s 175us/step - loss: 0.0138 - mean_absolute_error: 0.0920 - mean_squared_error: 0.0138 - val_loss: 0.0133 - val_mean_absolute_error: 0.0923 - val_mean_squared_error: 0.0133
# Epoch 50/70
# 1819/1819 [==============================] - 0s 188us/step - loss: 0.0139 - mean_absolute_error: 0.0925 - mean_squared_error: 0.0139 - val_loss: 0.0134 - val_mean_absolute_error: 0.0928 - val_mean_squared_error: 0.0134
# Epoch 51/70
# 1819/1819 [==============================] - 0s 173us/step - loss: 0.0140 - mean_absolute_error: 0.0929 - mean_squared_error: 0.0140 - val_loss: 0.0136 - val_mean_absolute_error: 0.0931 - val_mean_squared_error: 0.0136
# Epoch 52/70
# 1819/1819 [==============================] - 0s 174us/step - loss: 0.0139 - mean_absolute_error: 0.0927 - mean_squared_error: 0.0139 - val_loss: 0.0136 - val_mean_absolute_error: 0.0936 - val_mean_squared_error: 0.0136
# Epoch 53/70
# 1819/1819 [==============================] - 0s 185us/step - loss: 0.0141 - mean_absolute_error: 0.0939 - mean_squared_error: 0.0141 - val_loss: 0.0135 - val_mean_absolute_error: 0.0932 - val_mean_squared_error: 0.0135
# Epoch 54/70
# 1819/1819 [==============================] - 0s 187us/step - loss: 0.0140 - mean_absolute_error: 0.0923 - mean_squared_error: 0.0140 - val_loss: 0.0134 - val_mean_absolute_error: 0.0928 - val_mean_squared_error: 0.0134
# Epoch 55/70
# 1819/1819 [==============================] - 0s 171us/step - loss: 0.0138 - mean_absolute_error: 0.0925 - mean_squared_error: 0.0138 - val_loss: 0.0137 - val_mean_absolute_error: 0.0932 - val_mean_squared_error: 0.0137
# Epoch 56/70
# 1819/1819 [==============================] - 0s 186us/step - loss: 0.0141 - mean_absolute_error: 0.0933 - mean_squared_error: 0.0141 - val_loss: 0.0133 - val_mean_absolute_error: 0.0921 - val_mean_squared_error: 0.0133
# Epoch 57/70
# 1819/1819 [==============================] - 0s 190us/step - loss: 0.0138 - mean_absolute_error: 0.0920 - mean_squared_error: 0.0138 - val_loss: 0.0132 - val_mean_absolute_error: 0.0918 - val_mean_squared_error: 0.0132
# Epoch 58/70
# 1819/1819 [==============================] - 0s 180us/step - loss: 0.0138 - mean_absolute_error: 0.0925 - mean_squared_error: 0.0138 - val_loss: 0.0133 - val_mean_absolute_error: 0.0924 - val_mean_squared_error: 0.0133
# Epoch 59/70
# 1819/1819 [==============================] - 0s 188us/step - loss: 0.0139 - mean_absolute_error: 0.0918 - mean_squared_error: 0.0139 - val_loss: 0.0136 - val_mean_absolute_error: 0.0929 - val_mean_squared_error: 0.0136
# Epoch 60/70
# 1819/1819 [==============================] - 0s 172us/step - loss: 0.0140 - mean_absolute_error: 0.0930 - mean_squared_error: 0.0140 - val_loss: 0.0135 - val_mean_absolute_error: 0.0927 - val_mean_squared_error: 0.0135
# Epoch 61/70
# 1819/1819 [==============================] - 0s 181us/step - loss: 0.0139 - mean_absolute_error: 0.0927 - mean_squared_error: 0.0139 - val_loss: 0.0141 - val_mean_absolute_error: 0.0955 - val_mean_squared_error: 0.0141
# Epoch 62/70
# 1819/1819 [==============================] - 0s 187us/step - loss: 0.0139 - mean_absolute_error: 0.0926 - mean_squared_error: 0.0139 - val_loss: 0.0139 - val_mean_absolute_error: 0.0949 - val_mean_squared_error: 0.0139
# Epoch 63/70
# 1819/1819 [==============================] - 0s 170us/step - loss: 0.0141 - mean_absolute_error: 0.0936 - mean_squared_error: 0.0141 - val_loss: 0.0134 - val_mean_absolute_error: 0.0927 - val_mean_squared_error: 0.0134
# Epoch 64/70
# 1819/1819 [==============================] - 0s 170us/step - loss: 0.0139 - mean_absolute_error: 0.0926 - mean_squared_error: 0.0139 - val_loss: 0.0136 - val_mean_absolute_error: 0.0929 - val_mean_squared_error: 0.0136
# Epoch 65/70
# 1819/1819 [==============================] - 0s 180us/step - loss: 0.0137 - mean_absolute_error: 0.0915 - mean_squared_error: 0.0137 - val_loss: 0.0133 - val_mean_absolute_error: 0.0922 - val_mean_squared_error: 0.0133
# Epoch 66/70
# 1819/1819 [==============================] - 0s 197us/step - loss: 0.0137 - mean_absolute_error: 0.0918 - mean_squared_error: 0.0137 - val_loss: 0.0137 - val_mean_absolute_error: 0.0932 - val_mean_squared_error: 0.0137
# Epoch 67/70
# 1819/1819 [==============================] - 0s 168us/step - loss: 0.0137 - mean_absolute_error: 0.0919 - mean_squared_error: 0.0137 - val_loss: 0.0136 - val_mean_absolute_error: 0.0926 - val_mean_squared_error: 0.0136
# Epoch 68/70
# 1819/1819 [==============================] - 0s 177us/step - loss: 0.0140 - mean_absolute_error: 0.0929 - mean_squared_error: 0.0140 - val_loss: 0.0136 - val_mean_absolute_error: 0.0927 - val_mean_squared_error: 0.0136
# Epoch 69/70
# 1819/1819 [==============================] - 0s 172us/step - loss: 0.0136 - mean_absolute_error: 0.0916 - mean_squared_error: 0.0136 - val_loss: 0.0135 - val_mean_absolute_error: 0.0932 - val_mean_squared_error: 0.0135
# Epoch 70/70
# 1819/1819 [==============================] - 0s 189us/step - loss: 0.0138 - mean_absolute_error: 0.0923 - mean_squared_error: 0.0138 - val_loss: 0.0137 - val_mean_absolute_error: 0.0935 - val_mean_squared_error: 0.0137

# %%
# Выводим динамику среднего абсолютного отклонения от номера эпохи обучения.
plt.plot(history.history['mean_absolute_error'])
plt.plot(history.history['val_mean_absolute_error']) 
plt.title('Model MAE') 
plt.ylabel('MAE') 
plt.xlabel('Epoch') 
plt.legend(['Train', 'Test'], loc='upper right') 
plt.show()

# %%
# Выводим динамику среднеквадратического отклонения, т.е. значения функции потерь, от номера эпохи обучения.
plt.plot(history.history['mean_squared_error'])
plt.plot(history.history['val_mean_squared_error']) 
plt.title('Model MSE') 
plt.ylabel('MSE') 
plt.xlabel('Epoch') 
plt.legend(['Train', 'Test'], loc='upper right') 
plt.show()

# %%
# Предсказание уже обученной нейронной сети на обучающей выборке:
Y_pred_train = model.predict(X_train).flatten()

# %%
# Сравним эталонные значения Y_train и результат работы обученной нейронной сети Y_pred_train для обучающей выборки.
plt.plot(Y_train, Y_pred_train, 'bo')
plt.plot([-2,2], [-2,2], 'r-')
plt.title('Test vs Pred_test') 
plt.ylabel('Pred_test') 
plt.xlabel('Test') 
plt.show()

# %%
# Выведем сами значения Y_train и Y_pred_train.
plt.plot(Y_train)
plt.plot(Y_pred_train)
plt.show()

# %%
# Предсказание обученной нейронной сети на тестовой выборке:
Y_pred_test = model.predict(X_test).flatten()

# %%
# Сравним эталонные значения Y_test и результат работы обученной нейронной сети Y_pred_test для тестовой выборки.
plt.plot(Y_test, Y_pred_test, 'bo')
plt.plot([-2,2], [-2,2], 'r-')
plt.title('Test vs Pred_test') 
plt.ylabel('Pred_test') 
plt.xlabel('Test') 
plt.show()

# %%
# Выведем сами значения Y_test и Y_pred_test.
plt.plot(Y_test)
plt.plot(Y_pred_test)
plt.show()

# %%
# Сравним среднеквадратичные ошибки (значения функции потерь) для обучающей и тестовой выборок.
print(np.sqrt(mean_squared_error(Y_train, Y_pred_train)))
print(np.sqrt(mean_squared_error(Y_test, Y_pred_test)))
# Out:
# 0.11686208948773691
# 0.11693758562458079

# %%
# Проверим на нормальное распределение разности пар (Y_train, Y_pred_train), (Y_test, Y_pred_test)
k_train, p_train = stats.shapiro(Y_train - Y_pred_train)
print('Train k = {0}, p = {1}'.format(k_train, p_train))

k_test, p_test = stats.shapiro(Y_test - Y_pred_test)
print('Test k = {0}, p = {1}'.format(k_test, p_test))
# Out:
# Train k = 0.997475266456604, p = 0.005215318873524666
# Test k = 0.9960756301879883, p = 0.3221745193004608

# %%
# Для полной выборки (Y, Y_pred) применим два статистических теста: shapiro и normaltest.
Y_pred = model.predict(X).flatten()

k_s, p_s = stats.shapiro(Y - Y_pred)
print('k_s = {0}, p_s = {1}'.format(k_s, p_s))

k_n, p_n = stats.normaltest(Y - Y_pred)
print('k_n = {0}, p_n = {1}'.format(k_n, p_n))
# Out:
# k_s = 0.9978066086769104, p_s = 0.0030585459899157286
# k_n = 9.007392275206126, p_n = 0.011068011947407691

# %%
# И тоже самое визуально, с помощью грфиков квантиль-квантиль.
# Обучающая выборка
qqplot(Y_train - Y_pred_train)
plt.show()

# %%
# Тестовая выборка
qqplot(Y_test - Y_pred_test)
plt.show()

# %%
# Полная выборка
qqplot(Y - Y_pred)
plt.show()

# %%
plt.hist(Y - Y_pred, bins=50)
plt.show()

# %%
model.save('SimpleNeuralNetwork.h5')
