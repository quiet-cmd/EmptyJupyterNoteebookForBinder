# %%
import numpy as np
import matplotlib.pyplot as plt

plt.plot(1/np.array(range(-10,11)))
plt.show()
# Out:
# <ipython-input-18-6f4e54e709e0>:5: RuntimeWarning: divide by zero encountered in true_divide
#   plt.plot(1/np.array(range(-10,11)))
