# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.array(range(-200,200))
y = 1/x

plt.plot(x, y)
plt.title('hyperbola')
plt.grid(True)
plt.show()
# Out:
# <ipython-input-129-425b11c64268>:5: RuntimeWarning: divide by zero encountered in true_divide
#   y = 1/x
